# %%
import pandas as pd
import matplotlib.pyplot as plt

# Import data
h_2015 = pd.read_csv("2015.csv")
h_2016 = pd.read_csv("2016.csv")
h_2017 = pd.read_csv("2017.csv")
h_2018 = pd.read_csv("2018.csv")
h_2019 = pd.read_csv("2019.csv")

h_2015["Year"] = "2015"
h_2016["Year"] = "2016"
h_2017["Year"] = "2017"
h_2018["Year"] = "2018"
h_2019["Year"] = "2019"

h_2015 = h_2015.drop(columns=['Standard Error', 'Dystopia Residual', 'Region', "Happiness Rank" ])

h_2015.rename(columns={"Country": "Country Region"},inplace=True)

h_2016 = h_2016.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual', "Happiness Rank", "Region"])

h_2016.rename(columns={"Country": "Country Region"},inplace=True)

h_2017 = h_2017.drop(columns=['Whisker.high', 'Whisker.low', 'Dystopia.Residual', "Happiness.Rank"])

h_2017.rename(columns={"Happiness.Score": "Happiness Score", "Country": "Country Region", "Economy..GDP.per.Capita.": "Economy (GDP per Capita)", "Health..Life.Expectancy.": "Health (Life Expectancy)", "Trust..Government.Corruption.": "Trust (Government Corruption)"},inplace=True)

h_2018.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


h_2018 = h_2018.drop(["Overall rank"], axis=1)

h_2019 = h_2019.drop(["Overall rank"], axis=1)

h_2019.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


frames = [h_2015, h_2016, h_2017, h_2018, h_2019]

df = pd.concat(frames)


df2 = df.loc[(df['Country Region']=='Canada'), :]
df3 = df.loc[(df['Country Region']=='Iceland'), :]
df4 = df.loc[(df['Country Region']=='Switzerland'), :]
df5 = df.loc[(df['Country Region']=='Denmark'), :]
df6 = df.loc[(df['Country Region']=='Norway'), :]

plt.figure(figsize=(25,6))
plt.plot(df2["Year"],df2["Happiness Score"])
plt.plot(df3["Year"],df3["Happiness Score"])
plt.plot(df4["Year"],df4["Happiness Score"])
plt.plot(df5["Year"],df5["Happiness Score"])
plt.plot(df6["Year"],df6["Happiness Score"])
plt.grid()
plt.title('Happiness Score for Top 5 Countries')
plt.ylabel('Happiness')
plt.xlabel('Years')


plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import numpy as np
#sns.set(color_codes=True, font_scale=1.2)


h_2015 = pd.read_csv("2015.csv").dataframeName = h_2015
corr = h_2015.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(2, 250, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
# Out:
# C:\Users\florencia\AppData\Local\Temp\ipykernel_5700\3448044814.py:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   h_2015 = pd.read_csv("2015.csv").dataframeName = h_2015

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import numpy as np
#sns.set(color_codes=True, font_scale=1.2)

h_2015 = pd.read_csv("2015.csv")
h_2016 = pd.read_csv("2016.csv")
h_2017 = pd.read_csv("2017.csv")
h_2018 = pd.read_csv("2018.csv")
h_2019 = pd.read_csv("2019.csv")

h_2015["Year"] = "2015"
h_2016["Year"] = "2016"
h_2017["Year"] = "2017"
h_2018["Year"] = "2018"
h_2019["Year"] = "2019"

h_2015 = h_2015.drop(columns=['Standard Error', 'Dystopia Residual', 'Region', "Happiness Rank" ])

h_2015.rename(columns={"Country": "Country Region"},inplace=True)

h_2016 = h_2016.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual', "Happiness Rank", "Region"])

h_2016.rename(columns={"Country": "Country Region"},inplace=True)

h_2017 = h_2017.drop(columns=['Whisker.high', 'Whisker.low', 'Dystopia.Residual', "Happiness.Rank"])

h_2017.rename(columns={"Happiness.Score": "Happiness Score", "Country": "Country Region", "Economy..GDP.per.Capita.": "Economy (GDP per Capita)", "Health..Life.Expectancy.": "Health (Life Expectancy)", "Trust..Government.Corruption.": "Trust (Government Corruption)"},inplace=True)

h_2018.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


h_2018 = h_2018.drop(["Overall rank"], axis=1)

h_2019 = h_2019.drop(["Overall rank"], axis=1)

h_2019.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


frames = [h_2015, h_2016, h_2017, h_2018, h_2019]

df = pd.concat(frames)

df = df.groupby("Year")["Happiness Score"].mean()

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import numpy as np
#sns.set(color_codes=True, font_scale=1.2)

plt.rcParams['figure.figsize']=(15,7)

h_2015 = pd.read_csv("2015.csv").dataframeName = h_2015
df = h_2015[['Freedom', 'Happiness Score', 'Country']].head(5)
df2 = h_2015[['Freedom', 'Happiness Score', 'Country']].tail(5)


plt.bar(df["Country"],df["Freedom"])
plt.bar(df2["Country"],df2["Freedom"])
# Out:
# C:\Users\florencia\AppData\Local\Temp\ipykernel_13788\3541209096.py:8: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   h_2015 = pd.read_csv("2015.csv").dataframeName = h_2015
# <BarContainer object of 5 artists>

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import numpy as np
#sns.set(color_codes=True, font_scale=1.2)

plt.rcParams['figure.figsize']=(15,7)

h_2015 = pd.read_csv("2015.csv").dataframeName = h_2015
df = h_2015.groupby('Region')['Happiness Score'].mean()
df.plot.pie(autopct = '%1.1f%%')
# Out:
# C:\Users\florencia\AppData\Local\Temp\ipykernel_13788\1634725494.py:8: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   h_2015 = pd.read_csv("2015.csv").dataframeName = h_2015
# <AxesSubplot:ylabel='Happiness Score'>

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import numpy as np
#sns.set(color_codes=True, font_scale=1.2)

h_2015 = pd.read_csv("2015.csv")
h_2016 = pd.read_csv("2016.csv")
h_2017 = pd.read_csv("2017.csv")
h_2018 = pd.read_csv("2018.csv")
h_2019 = pd.read_csv("2019.csv")

h_2015["Year"] = "2015"
h_2016["Year"] = "2016"
h_2017["Year"] = "2017"
h_2018["Year"] = "2018"
h_2019["Year"] = "2019"

h_2015 = h_2015.drop(columns=['Standard Error', 'Dystopia Residual', 'Region', "Happiness Rank" ])

h_2015.rename(columns={"Country": "Country Region"},inplace=True)

h_2016 = h_2016.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual', "Happiness Rank", "Region"])

h_2016.rename(columns={"Country": "Country Region"},inplace=True)

h_2017 = h_2017.drop(columns=['Whisker.high', 'Whisker.low', 'Dystopia.Residual', "Happiness.Rank"])

h_2017.rename(columns={"Happiness.Score": "Happiness Score", "Country": "Country Region", "Economy..GDP.per.Capita.": "Economy (GDP per Capita)", "Health..Life.Expectancy.": "Health (Life Expectancy)", "Trust..Government.Corruption.": "Trust (Government Corruption)"},inplace=True)

h_2018.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


h_2018 = h_2018.drop(["Overall rank"], axis=1)

h_2019 = h_2019.drop(["Overall rank"], axis=1)

h_2019.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


frames = [h_2015, h_2016, h_2017, h_2018, h_2019]

df = pd.concat(frames)

df1 = df.groupby("Year")["Economy (GDP per Capita)"].mean()
df2 = df.groupby("Year")["Freedom"].mean()
plt.plot(df1, 'r+')
plt.plot(df2, 'bo')

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import numpy as np
#sns.set(color_codes=True, font_scale=1.2)

h_2015 = pd.read_csv("2015.csv")
h_2016 = pd.read_csv("2016.csv")
h_2017 = pd.read_csv("2017.csv")
h_2018 = pd.read_csv("2018.csv")
h_2019 = pd.read_csv("2019.csv")

h_2015["Year"] = "2015"
h_2016["Year"] = "2016"
h_2017["Year"] = "2017"
h_2018["Year"] = "2018"
h_2019["Year"] = "2019"

h_2015 = h_2015.drop(columns=['Standard Error', 'Dystopia Residual', 'Region', "Happiness Rank" ])

h_2015.rename(columns={"Country": "Country Region"},inplace=True)

h_2016 = h_2016.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual', "Happiness Rank", "Region"])

h_2016.rename(columns={"Country": "Country Region"},inplace=True)

h_2017 = h_2017.drop(columns=['Whisker.high', 'Whisker.low', 'Dystopia.Residual', "Happiness.Rank"])

h_2017.rename(columns={"Happiness.Score": "Happiness Score", "Country": "Country Region", "Economy..GDP.per.Capita.": "Economy (GDP per Capita)", "Health..Life.Expectancy.": "Health (Life Expectancy)", "Trust..Government.Corruption.": "Trust (Government Corruption)"},inplace=True)

h_2018.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


h_2018 = h_2018.drop(["Overall rank"], axis=1)

h_2019 = h_2019.drop(["Overall rank"], axis=1)

h_2019.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


frames = [h_2015, h_2016, h_2017, h_2018, h_2019]

df = pd.concat(frames)

df1 = df[['Happiness Score', 'Freedom', 'Economy (GDP per Capita)', 'Trust (Government Corruption)', 'Family']].corr()
plt.plot(df1)

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import numpy as np
#sns.set(color_codes=True, font_scale=1.2)

h_2015 = pd.read_csv("2015.csv")
h_2016 = pd.read_csv("2016.csv")
h_2017 = pd.read_csv("2017.csv")
h_2018 = pd.read_csv("2018.csv")
h_2019 = pd.read_csv("2019.csv")

h_2015["Year"] = "2015"
h_2016["Year"] = "2016"
h_2017["Year"] = "2017"
h_2018["Year"] = "2018"
h_2019["Year"] = "2019"

h_2015 = h_2015.drop(columns=['Standard Error', 'Dystopia Residual', 'Region', "Happiness Rank" ])

h_2015.rename(columns={"Country": "Country Region"},inplace=True)

h_2016 = h_2016.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual', "Happiness Rank", "Region"])

h_2016.rename(columns={"Country": "Country Region"},inplace=True)

h_2017 = h_2017.drop(columns=['Whisker.high', 'Whisker.low', 'Dystopia.Residual', "Happiness.Rank"])

h_2017.rename(columns={"Happiness.Score": "Happiness Score", "Country": "Country Region", "Economy..GDP.per.Capita.": "Economy (GDP per Capita)", "Health..Life.Expectancy.": "Health (Life Expectancy)", "Trust..Government.Corruption.": "Trust (Government Corruption)"},inplace=True)

h_2018.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


h_2018 = h_2018.drop(["Overall rank"], axis=1)

h_2019 = h_2019.drop(["Overall rank"], axis=1)

h_2019.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


frames = [h_2015, h_2016, h_2017, h_2018, h_2019]

df = pd.concat(frames)
plt.figure(figsize = (10, 5))

df.head()

df1 = df[['Happiness Score', 'Freedom', 'Economy (GDP per Capita)', 'Trust (Government Corruption)', 'Family']].mean()
ax = df1.plot(kind='bar', x=df1, y='Avg')

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
#sns.set(color_codes=True, font_scale=1.2)

h_2015 = pd.read_csv("2015.csv")
h_2016 = pd.read_csv("2016.csv")
h_2017 = pd.read_csv("2017.csv")
h_2018 = pd.read_csv("2018.csv")
h_2019 = pd.read_csv("2019.csv")

h_2015["Year"] = "2015"
h_2016["Year"] = "2016"
h_2017["Year"] = "2017"
h_2018["Year"] = "2018"
h_2019["Year"] = "2019"

h_2015 = h_2015.drop(columns=['Standard Error', 'Dystopia Residual', 'Region', "Happiness Rank" ])

h_2015.rename(columns={"Country": "Country Region"},inplace=True)

h_2016 = h_2016.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual', "Happiness Rank", "Region"])

h_2016.rename(columns={"Country": "Country Region"},inplace=True)

h_2017 = h_2017.drop(columns=['Whisker.high', 'Whisker.low', 'Dystopia.Residual', "Happiness.Rank"])

h_2017.rename(columns={"Happiness.Score": "Happiness Score", "Country": "Country Region", "Economy..GDP.per.Capita.": "Economy (GDP per Capita)", "Health..Life.Expectancy.": "Health (Life Expectancy)", "Trust..Government.Corruption.": "Trust (Government Corruption)"},inplace=True)

h_2018.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


h_2018 = h_2018.drop(["Overall rank"], axis=1)

h_2019 = h_2019.drop(["Overall rank"], axis=1)

h_2019.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


frames = [h_2015, h_2016, h_2017, h_2018, h_2019]

df = pd.concat(frames)
plt.figure(figsize = (20, 5))
df2 = df.loc[(df['Country Region'].isin(['Iceland', 'Canada', 'Norway', 'Denmark', 'Switzerland'])), :]
df1 = df2[['Happiness Score', 'Freedom', 'Economy (GDP per Capita)', 'Trust (Government Corruption)', 'Family', 'Year', 'Country Region']]
sns.set_style(style='whitegrid')

sns.scatterplot(
    data=df1, 
    x='Economy (GDP per Capita)', 
    y='Happiness Score',
    hue="Country Region",
    style="Year",
    )
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
#sns.set(color_codes=True, font_scale=1.2)

h_2015 = pd.read_csv("2015.csv")
h_2016 = pd.read_csv("2016.csv")
h_2017 = pd.read_csv("2017.csv")
h_2018 = pd.read_csv("2018.csv")
h_2019 = pd.read_csv("2019.csv")

h_2015["Year"] = "2015"
h_2016["Year"] = "2016"
h_2017["Year"] = "2017"
h_2018["Year"] = "2018"
h_2019["Year"] = "2019"

h_2015 = h_2015.drop(columns=['Standard Error', 'Dystopia Residual', 'Region', "Happiness Rank" ])

h_2015.rename(columns={"Country": "Country Region"},inplace=True)

h_2016 = h_2016.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual', "Happiness Rank", "Region"])

h_2016.rename(columns={"Country": "Country Region"},inplace=True)

h_2017 = h_2017.drop(columns=['Whisker.high', 'Whisker.low', 'Dystopia.Residual', "Happiness.Rank"])

h_2017.rename(columns={"Happiness.Score": "Happiness Score", "Country": "Country Region", "Economy..GDP.per.Capita.": "Economy (GDP per Capita)", "Health..Life.Expectancy.": "Health (Life Expectancy)", "Trust..Government.Corruption.": "Trust (Government Corruption)"},inplace=True)

h_2018.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


h_2018 = h_2018.drop(["Overall rank"], axis=1)

h_2019 = h_2019.drop(["Overall rank"], axis=1)

h_2019.rename(columns={"Score": "Happiness Score", "Country or region": "Country Region", "GDP per capita": "Economy (GDP per Capita)", "Healthy life expectancy": "Health (Life Expectancy)", "Perceptions of corruption": "Trust (Government Corruption)",
                      "Social support":"Family", "Freedom to make life choices":"Freedom"},inplace=True)


frames = [h_2015, h_2016, h_2017, h_2018, h_2019]

df = pd.concat(frames)
plt.figure(figsize = (20, 5))
df1 = df[['Happiness Score', 'Freedom', 'Economy (GDP per Capita)', 'Trust (Government Corruption)', 'Family', 'Year', 'Country Region']]
sns.set_style(style='whitegrid')

sns.scatterplot(
    data=df1, 
    x='Economy (GDP per Capita)', 
    y='Happiness Score',
    hue="Country Region",
    style="Year",
    )
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
import plotly.express as px

frames = [h_2015, h_2016, h_2017, h_2018, h_2019]

df = pd.concat(frames)
plt.figure(figsize = (20, 5))
df1 = df[['Happiness Score', 'Freedom', 'Economy (GDP per Capita)', 'Trust (Government Corruption)', 'Family', 'Year', 'Country Region']]

fig1 = px.scatter(df1,x = "Happiness Score", y = "Economy (GDP per Capita)", title = "HAPPINESS SCORE VS GDP PER CAPITA ")
fig1.show()
# Out:
# <div>                            <div id="cb365381-ce81-4b3d-99f0-0c078bdd65cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb365381-ce81-4b3d-99f0-0c078bdd65cc")) {                    Plotly.newPlot(                        "cb365381-ce81-4b3d-99f0-0c078bdd65cc",                        [{"hovertemplate":"Happiness Score=%{x}<br>Economy (GDP per Capita)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[7.587,7.561,7.527,7.522,7.427,7.406,7.378,7.364,7.286,7.284,7.278,7.226,7.2,7.187,7.119,6.983,6.946,6.94,6.937,6.901,6.867,6.853,6.81,6.798,6.786,6.75,6.67,6.611,6.575,6.574,6.505,6.485,6.477,6.455,6.411,6.329,6.302,6.298,6.295,6.269,6.168,6.13,6
# ...

# %%
import plotly.express as px

frames = [h_2015, h_2016, h_2017, h_2018, h_2019]

df = pd.concat(frames)
plt.figure(figsize = (20, 5))
df1 = df[['Happiness Score', 'Freedom', 'Economy (GDP per Capita)', 'Trust (Government Corruption)', 'Family', 'Year', 'Country Region']]

fig1 = px.scatter(df1,x = "Happiness Score", y = "Freedom", title = "HAPPINESS SCORE VS FREEDOM ")
fig1.show()
# Out:
# <div>                            <div id="4baab9cc-ab63-46ba-bba6-669aeb797c9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4baab9cc-ab63-46ba-bba6-669aeb797c9d")) {                    Plotly.newPlot(                        "4baab9cc-ab63-46ba-bba6-669aeb797c9d",                        [{"hovertemplate":"Happiness Score=%{x}<br>Freedom=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[7.587,7.561,7.527,7.522,7.427,7.406,7.378,7.364,7.286,7.284,7.278,7.226,7.2,7.187,7.119,6.983,6.946,6.94,6.937,6.901,6.867,6.853,6.81,6.798,6.786,6.75,6.67,6.611,6.575,6.574,6.505,6.485,6.477,6.455,6.411,6.329,6.302,6.298,6.295,6.269,6.168,6.13,6.123,6.003,5.995,
# ...

# %%
corr = df.corr()

sns.heatmap(corr,
          mask=mask,
          annot=True,
          linewidths=.5,
            cmap="Blues",
          square=True)
# Out:
# <AxesSubplot:>

# %%
df = pd.concat(frames)
plt.figure(figsize = (20, 5))
df2 = df.loc[(df['Country Region'].isin(['Iceland', 'Canada', 'Norway', 'Denmark', 'Switzerland'])), :]
df1 = df2[['Happiness Score', 'Freedom', 'Economy (GDP per Capita)', 'Trust (Government Corruption)', 'Family', 'Year', 'Country Region']]


sns.catplot(x='Year', 
            y='Economy (GDP per Capita)',
            data=df,
            kind='box');
